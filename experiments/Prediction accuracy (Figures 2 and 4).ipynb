# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# accuraccy.npy figure 2 ,accuraccy_figure4.npy figure 4  
#acc = np.load("accuraccy_figure4.npy")
acc = np.load("accuraccy.npy") #figure 2

fig, big_axes = plt.subplots( figsize=(14.0, 14.0) , nrows=3, ncols=1, sharey=True) 

for i, big_ax in enumerate(big_axes, start=1):
    big_ax.set_title("Agent %s predictions \n" % i, fontsize=18)
    

    # Turn off axis lines and ticks of the big subplot 
    # obs alpha is 0 in RGBA string!
    big_ax.tick_params(labelcolor=(1.,1.,1., 0.0), top='off', bottom='off', left='off', right='off')
    # removes the white frame
    big_ax._frameon = False
         
    
    
for i in range(3):
    for j in range(3):
        ax = fig.add_subplot(3,3, i*3 + j + 1)
        ax.set_title('Agent ' + str(j + 1) + '%s final landmark'  % (' (own)' if i == j else ''),color='dimgray' )
        ax.plot(acc[i, j, :, :, 1])
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)
        plt.ylim(0, 1)
        plt.xlabel('Steps')
        plt.legend(['observation', 'hidden 1', 'hidden 2', 'action'], loc='lower right')
        #if j== 0:
        plt.ylabel('Accuracy')
    
    

fig.set_facecolor('w')
plt.tight_layout()
plt.savefig('coop_navi_shuffle_episode_1.png', format='png', dpi=300)
#plt.savefig('coop_navi_1.png', format='png', dpi=300) #figure4

plt.show()
