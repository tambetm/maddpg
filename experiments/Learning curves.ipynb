# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open("learning_curves/coop_navi_ensemble_1_rewards.pkl", "rb") as f:
    episode_rewards = pickle.load(f)

# %%
plt.plot(episode_rewards)

# %%
with open("learning_curves/coop_navi_ensemble_1_agrewards.pkl", "rb") as f:
    agent_rewards = pickle.load(f)

# %%
agent_rewards = np.reshape(agent_rewards, (-1, 3))

# %%
plt.plot(agent_rewards)

# %%
plt.figure(figsize=(16,4))
plt.subplot(1, 3, 1)
plt.plot(agent_rewards[:, 0])
plt.title("Agent 1")
plt.subplot(1, 3, 2)
plt.plot(agent_rewards[:, 1])
plt.title("Agent 2")
plt.subplot(1, 3, 3)
plt.plot(agent_rewards[:, 2])
plt.title("Agent 3")
# Out:
# Text(0.5,1,'Agent 3')

# %%
agent_rewards
# Out:
# array([[-73.94783951, -73.92383951, -73.94883951],
#        [-80.19946757, -80.18246757, -80.05146757],
#        [-63.10032336, -63.45132336, -63.65532336],
#        [-59.36692077, -59.63192077, -59.67992077],
#        [-56.7769634 , -56.6929634 , -56.6159634 ],
#        [-54.79278675, -54.70478675, -54.66678675],
#        [-54.64800499, -54.48900499, -54.50500499],
#        [-53.62444862, -53.51244862, -53.35344862],
#        [-52.56410811, -52.51610811, -52.45410811],
#        [-51.64605647, -51.60305647, -51.49405647],
#        [-51.67661763, -51.53061763, -51.54661763],
#        [-50.68830092, -50.69130092, -50.59030092],
#        [-50.17565331, -50.31065331, -50.35865331],
#        [-50.01854228, -50.14154228, -50.08754228],
#        [-49.58239756, -49.74839756, -49.65639756],
#        [-49.5243529 , -49.6003529 , -49.5313529 ],
#        [-49.55785332, -49.71885332, -49.54485332],
#        [-49.01317975, -48.95117975, -49.02317975],
# ...
